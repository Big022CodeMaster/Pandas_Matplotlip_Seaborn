# %%
# numpy, pandas und pyplot importieren
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Wir arbeiten heute mit dem Iris Datensatz
# Dieser ist sauber und muss daher nicht groß Vorbereitet werden
import seaborn as sns
df = sns.load_dataset('iris')

# %%
# Daten kennenlernen
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
# Bestimme, welche species es gibt
df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
# Scatterplot: sepal_length vs petal_length
plt.scatter(df.sepal_length,df.petal_length);

# %%
# Führe nochmals den Scatterplot durch, jedoch
# unterscheide farblich nach den Spezies
plt.scatter('sepal_length','petal_length', data=df[df['species']== 'setosa'],c='darkblue')
plt.scatter('sepal_length','petal_length', data=df[df.species== 'versicolor'],c='darkgreen')
plt.scatter('sepal_length','petal_length', data=df[df.species== 'virginica'],c='orange')
#plt.legend(['species ' + str(i) for i in range(1, 4)])

plt.legend(df.species.unique())

plt.show()

#sns.scatterplot('sepal_length','petal_length',hue='species',data=df)

#plt.scatter('sepal_length','petal_length', data=df.species.unique()) will not work

# %%
# Bilde ein subplots: wie soeben mit den Längen, 
# soll im zweiten Plot die Breite verglichen werden

# %%
sns.scatterplot('sepal_length','petal_length',hue='species',data=df)
# Out:
# c:\Python3104\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
# Verwende die Specie Setosa
# Erstelle für jedes Merkmal ein Boxplot
# binde die Diagramme in ein 2x2 subplots ein
#plt.figure(figsize=(15,8))
fig,axes= plt.subplots(2,2,figsize=(15,7))
fig.set_facecolor('lightblue')
axes[0,0].scatter(df.petal_length,df.species=='setosa')

# %%
#sns.boxplot('sepal_length','petal_length',hue='species',data=df)

# %%
# Weitere Plots nach belieben!

# %%
# oder einen neuen Datensatz nehmen
# FYI: Diamonds lässt sich gut plotten, jedoch viele Daten
# FYI: penguins ist auch nett zum Plotten
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# fig.savefig(“figure.pdf”)
# fig.show()

# %%
df1=sns.load_dataset('penguins')
df1.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df1.loc[:,'sex'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
df1=df1.dropna()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 333 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    object
#  1   island             333 non-null    object
#  2   bill_length_mm     333 non-null    float64
#  3   bill_depth_mm      333 non-null    float64
#  4   flipper_length_mm  333 non-null    float64
#  5   body_mass_g        333 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.8+ KB

# %%
sns.scatterplot(x="flipper_length_mm", y="body_mass_g", hue="species",palette="ch:r=-.5,l=.75",data=df1)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
df1.island.unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
sns.relplot(x="flipper_length_mm", y="body_mass_g", size="species",palette="ch:r=-.5,l=.75",sizes=(15, 200),data=df1);

# %%
sns.relplot(x="flipper_length_mm", y="body_mass_g", hue="species",data=df1);

# %%
sns.catplot(x="species", y="body_mass_g", hue= "island",palette='crest',kind="swarm", data=df1);

# %%
sns.catplot(x="species", y="body_mass_g", hue="island", kind="swarm", data=df1);
